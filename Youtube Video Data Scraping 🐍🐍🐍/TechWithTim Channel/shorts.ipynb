# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time

# %%
URL = 'https://www.youtube.com/@TechWithTim/shorts'
browser = webdriver.Chrome()
browser.get(URL)
browser.maximize_window()
print(browser.title)
channel_name = browser.title
for _ in range (3):
    browser.find_element(By.TAG_NAME,'body').send_keys(Keys.END)
    time.sleep(3)
HTML = browser.page_source
browser.quit()
# Out:
# Tech With Tim - YouTube

# %%
soup = BeautifulSoup(HTML)
f=open(f'{channel_name}-shorts.csv','wb')
f.write('Shorts Name,Views\n'.encode())
for video in soup.find_all('div', id='dismissible'):
    title = video.find('h3').text.strip().replace(',',' ')
    meta = video.find('div',{'id':'metadata-line'}).find_all('span')
    Views = meta[0].text
    print(title,Views)
    f.write(f'{title},{Views}\n'.encode())
    print("\n")
f.close()
# Out:
# This Coding Project Gives You an UNFAIR Advantage 45K views
#
#
# Keep It Simple  Stupid. 18K views
#
#
# How Important Is Math For Machine Learning? 36K views
#
#
# Have You Learned Git? 28K views
#
#
# The Pros and Cons of Dropping Out (Computer Science) 13K views
#
#
# What Every Python Backend Developer Should Know 59K views
#
#
# Avoid This Common Programming Mistake! 214K views
#
#
# The Reason Why I Dropped Out Of Computer Science 46K views
#
#
# Avoid This If You Want To Be A Faster Programmer 37K views
#
#
# What To Do If You Can't Find A Bug 13K views
#
#
# Unique Coding Project Idea 36K views
#
#
# Is This The Programming Language Of The Future? 84K views
#
#
# Coding Project Idea To Land a Mobile Developer Job 17K views
#
#
# Amazing Project Idea For Web Developers 20K views
#
#
# Do This To Avoid Bugs When Programming 17K views
#
#
# How To Reference Documentation As A Programmer 26K views
#
#
# How To Prepare For Big Programming Projects 30K views
#
#
# How Should You Use ChatGPT As A Developer? 49K views
#
#
# Will AI Replace Programmers? 31K views
#
#
# How I Balance My Life As A Software Engineer 38K views
#
#
# The TOP 5 Beginner Programmer Mistakes 67K views
#
#
# How to Stay Motivated as a Self-Taught Developer 20K views
#
#
# My Top Tips For Computer Science Students 382K views
#
#
# How I Prepared For Microsoft and Shopify Coding Interviews 43K views
#
#
# The BEST Advice For Acing Your Tech Interviews 19K views
#
#
# Becoming a Self-Taught Developer 38K views
#
#
# The FASTEST Way To Become a Coding Content Creator 15K views
#
#
# Asynchronous Programming in a Nutshell 37K views
#
#
# Django VS Flask - Which Should You Learn 120K views
#
#
# 5 Tips For Writing Better Code 14K views
#
#
# The 45 Second Self Taught Developer Roadmap 39K views
#
#
# Should You Avoid Learning Python? One Surprising Reason to Consider 18K views
#
#
# How Much $$$ I Made From My 10 Million View Coding Livestream 125K views
#
#
# The BEST advice for junior developers 64K views
#
#
# Programming side hustles you can start TODAY 31K views
#
#
# 5 Python Modules Every Web Developer Must Learn 62K views
#
#
# The earning differences in Big Tech: US vs Non-US 221K views
#
#
# Python vs Javascript - Which should you learn? 127K views
#
#
# Get Inspired With This Advanced Programming Project Idea 21K views
#
#
# Why Python is the Perfect First Language to Learn 158K views
#
#
# Why Learning to Code is a Must 16K views
#
#
# The Truth About Machine Learning and AI Revealed 15K views
#
#
# The Underrated Skill That Can Make You a Great Programmer 12K views
#
#
# The Perfect Beginner Programming Project Idea 18K views
#
#
# One Of The TOP Habits of God-Tier Programmers! 11K views
#
#
# Understanding Network Communication: The Definition of a Packet Explained 8.2K views
#
#
# Automate Your Life With Code! 36K views
#
#
# What is Backend Programming? Explained in 60 Seconds! 11K views
#
#
# You Need a GOAL When Programming 9.7K views
#
#
# Avoid This Common Mistake as a Beginner Programmer 24K views
#
#
# The Importance of Learning Coding Fundamentals Before Advanced Concepts 19K views
#
#
# Learning Programming Design Patterns 92K views
#
#
# Reasons To Get a Software Engineering Degree 152K views
#
#
# Advice For Young Programmers 24K views
#
#
# Master Programming By Dividing and Conquering! 11K views
#
#
# What is an Algorithm? 8.1K views
#
#
# One Reason You May Struggle To Learn ML/AI 22K views
#
#
# Developers... Design Defensively🛡️⚔️ 12K views
#
#
# Please  Write REUSABLE Code 12K views
#
#
# DAPPs as Fast As Possible 5.9K views
#
#
# Understand a Blockchain in 40 Seconds 13K views
#
#
# How To Escape Tutorial HELL 12K views
#
#
# The WORST Debugging Mistake 10K views
#
#
# Bad At Debugging? Start Here! 13K views
#
#
# What is an API? 24K views
#
#
# Learn This Design Principle - Reduce Coupling! 11K views
#
#
# Make a Decentralized Exchange - Web 3 Project Idea 7.8K views
#
#
# My FAVOURITE Web 3 Project Idea 18K views
#
#
# Everyone Should Learn SOME Machine Learning 7.5K views
#
#
# Do These Projects To Get Better At Coding... 15K views
#
#
# Software Systems & Subsystems 6.2K views
#
#
# Software System Deployments 7.6K views
#
#
# How To SPEED Up Python Code 22K views
#
#
# The FOURTH Step To Rapidly Learn a New Programming Language 10K views
#
#
# The THIRD Step To Learn A Programming Language FAST 6.5K views
#
#
# The SECOND Step To Learn a New Programming Language 7.1K views
#
#
# The FIRST Step In Learning a New Programming Language 9.1K views
#
#
# Do You Have DOMAIN Knowledge? 11K views
#
#
# Master The Tools You Use Everyday 7.5K views
#
#
# The BEST Machine Learning Resume Project! 54K views
#
#
# Please Test Your Code! 11K views
#
#
# A GREAT Python Resume Project Idea 77K views
#
#
# Sometimes You Just Need a Break! 9.2K views
#
#
# The WORST Thing Beginner Programmers Do... 10K views
#
#
# The Best Part Of Programming... Debugging! 10K views
#
#
# Do You Have Good Programming Habits? 12K views
#
#
# Why You NEED To Learn System Design 20K views
#
#
# Python Developer... LEARN JavaScript 19K views
#
#
# Why You Should Learn C++ 226K views
#
#
# Python Developers... Learn DJANGO 127K views
#
#
# Learn THIS Language After Python... 18K views
#
#
# Why You NEED To Learn About Networking! 32K views
#
#
# Must KNOW Backend Developer Skills 9.5K views
#
#
# Are You Learning The Right Programming Language? 35K views
#
#
# Are You Writing TOO Much Code? 13K views
#
#
# A Stupid Simple Way To Be A Better Programmer 14K views
#
#
# Do This Before You Start Coding... 16K views
#
#
# Should You Code With Python? 77K views
#
#
# Biggest Opportunity For Programmers in 2023? 102K views
#
#
# A Super EASY Side Hustle For Programmers 25K views
#
#
# How to Land a Software Developer Job 41K views
#
#
# Programmers  STOP Burning Out 137K views
#
#
# The BEST Advice For Computer Science Students 153K views
#
#
# 2022 Programming Desk Setup - Overkill Edition #shorts 83K views
#
#
# Every Developer NEEDS This 316K views
#
#
# Python Easter Eggs You May Not Know 42K views
#
#
# How To Generate Random Numbers In Python 32K views
#
#
# How to Write To A FIle In Python 24K views
#
#
# How To Read From A File In Python 23K views
#
#
# How The Python Print Function Really Works... 29K views
#
#
# Lambdas in Python - One Line Anonymous Functions 26K views
#
#
# help() in Python - Read Documentation Quickly 117K views
#
#
# f-Strings in Python - String Formatting 49K views
#
#
# chr() & ord() in Python - Using ASCII Values 44K views
#
#
# bin() in Python - Convert Numbers To Binary & Decimal 71K views
#
#
# Splat Operator in Python (*  **) -  Unpack Iterables 159K views
#
#
# *args & **kwargs in Python - Accept Unlimited Arguments 68K views
#
#
# all() in Python - Check If All Items Are True 55K views
#
#
# any() in Python - Check If An Iterable Contains True 41K views
#
#
# zip() in Python - Combine Iterables Together 66K views
